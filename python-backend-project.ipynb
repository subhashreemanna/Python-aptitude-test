# %%
print("Welcome to the python aptitude test!")
name = input("Enter your name: ")

while not name.isalpha():
    print("Name should contain only alphabets.")
    name = input("Enter your name again: ")

print("Hello", name, "your Test is starting now.")

score = 0

Questions = [
    ["List can't store elements of different datatypes.","b"],
    ["Tuples are immutable.","a"],
    ["A set allows duplicate eliments.","b"],
    ["A dictionary stores data in key-value-pair.And key must be unique","a"],
    ["*Args allows variable number of positional arguments.","a"],
    ["**Kwargs is not used for variable number of Key word arguments.","b"],
    ["Try-except used for Error handling.","a"],
    ["In file handling 'W' mode overwrites a file.","a"],
    ["range(m,n) . in range function the end value will be n.","b"],
    ["Break stops a loop completely.","a"],
    ["continue skip the current iteration.","a"],
    ["Append() add item to the list at the first position.","b"],
    ["pop() removes last element from the list.","a"],
    ["python debugger is used to find error.","a"],
    ["Inheritance not allows a class to use properties and method of another class.","b"],
    ["Encapsulation means hiding the internal details of an object.","a"],
    ["List comprehension can replace simple for-loops used for building lists.","a"],
    ["The re.match() function checks for a pattern only at the beginning of a string.","a"],
    ["The symbol + in regex means 'zero or more times'.","b"],
    ["The symbol * in regex means 'zero or more times'.","a"],
    ["The __init__ method is called automatically when an object is created.","a"],
    ["The else block in a loop runs only when the loop is broken using 'break'.","b"],
    ["In a file 'r' mode used for reading.","a"],
    ["The finally block always executes, even if an error occurs.","a"],
    ["operator 'and' comes within logical operators.","a"]
]

options = ["a) True  b) False"]

question_number = 1

for q in Questions:
    print("Q", question_number, ".", q[0])
    print(options[0])

    answer = input("Enter your option (a/b): ").lower()
    
    while answer != "a" and answer != "b":
        print("Please enter only 'a' or 'b'")
        answer = input("Enter your option (a/b): ").lower()




    if answer == q[1]:
        print("Correct!")
        score = score + 1
    else:
        print("Incorrect!")

    print("----------------------------------")
    question_number += 1

print("Test completed!")
print(name, "Your final score is:", score, "out of 25")
